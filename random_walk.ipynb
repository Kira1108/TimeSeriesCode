# %%
from ts_gen import GaussianRandomWalk, SimpleRandomWalk
from plotting import plot_generator

# %%
plot_generator(
    SimpleRandomWalk(300), 
    title = 'Simple Random Walk')

# %%
plot_generator(
    GaussianRandomWalk(300), 
    title = 'Gaussian Random Walk')
